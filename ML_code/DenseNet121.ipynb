# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models, losses, Model
from typing import Tuple
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, ZeroPadding2D,\
     Flatten, BatchNormalization, AveragePooling2D, Dense, Activation, Add, AvgPool2D, GlobalAveragePooling2D, MaxPool2D 
from tensorflow.keras.models import Model
from tensorflow.keras import activations
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import ReLU, concatenate
import tensorflow.keras.backend as K
tf.compat.v1.enable_eager_execution()


os.environ["cuda_visible_devices"]="0" 

from glob import glob
import io
from PIL import Image

import math, re, os
import numpy as np

from collections import Counter

print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.8.0

# %%
if tf.test.gpu_device_name(): 

    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device:/device:GPU:0

# %%
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""PREPROCESSING"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# Out:
# 'PREPROCESSING'

# %%
IMAGE_SIZE = [224, 224]
PATH = '/content/drive/MyDrive/Colab_Notebooks/combined_data_splitted'

AUTO = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16

TRAIN_PATH = tf.io.gfile.glob(PATH + '/train/*.tfrecord')
VAL_PATH = tf.io.gfile.glob(PATH + '/validation/*.tfrecord')
TEST_PATH = tf.io.gfile.glob(PATH + '/test/*.tfrecord')

# %%
CLASSES = ['pink primrose',
 'wild geranium',
 'spear thistle',
 'yellow iris',
 'wallflower',
 'buttercup',
 'daisy',
 'common dandelion',
 'petunia',
 'sunflower',
 'iris',
 'windflower',
 'water lily',
 'rose',
 'morning glory',
 'frangipani',
 'cyclamen ',
 'foxglove',
 'common tulip',
 'wild rose']

# %%
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs


def load_dataset(filenames, labeled=True, ordered=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord, num_parallel_calls=AUTO)
    # returns a dataset of (image, label) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset

# %%
def data_augment(image, label):
    # Thanks to the dataset.prefetch(AUTO)
    # statement in the next function (below), this happens essentially
    # for free on TPU. Data pipeline code is executed on the "CPU"
    # part of the TPU while the TPU itself is computing gradients.
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_saturation(image, 0, 2)
    return image, label   


def get_training_dataset(path = TRAIN_PATH, labeled = True):
    dataset = load_dataset(path)
    dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    dataset = dataset.shuffle(6536)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(path = VAL_PATH):
    dataset = load_dataset(path)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

def get_test_dataset(path = TEST_PATH):
    dataset = load_dataset(path)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

# %%
ds_train = get_training_dataset()
ds_val = get_validation_dataset()
ds_test = get_test_dataset()

# %%
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""NETWORK DESIGN"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# Out:
# 'NETWORK DESIGN'

# %%
def densenet(input_shape, n_classes, filters = 32):
    
    #batch norm + relu + conv
    def bn_rl_conv(x,filters,kernel=1,strides=1):
        
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(filters, kernel, strides=strides,padding = 'same')(x)
        return x
    
    def dense_block(x, repetition):
        
        for _ in range(repetition):
            y = bn_rl_conv(x, 4*filters)
            y = bn_rl_conv(y, filters, 3)
            x = concatenate([y,x])
        return x
        
    def transition_layer(x):
        
        x = bn_rl_conv(x, K.int_shape(x)[-1] //2 )
        x = AvgPool2D(2, strides = 2, padding = 'same')(x)
        return x
    
    input = Input (input_shape)
    x = Conv2D(64, 7, strides = 2, padding = 'same')(input)
    x = MaxPool2D(3, strides = 2, padding = 'same')(x)
    
    for repetition in [6,12,24,16]:
        
        d = dense_block(x, repetition)
        x = transition_layer(d)
    x = GlobalAveragePooling2D()(d)
    output = Dense(n_classes, activation = 'softmax')(x)
    
    model = Model(input, output)
    return model

# %%
input_shape = 224, 224, 3
n_classes = 20

# %%
model = densenet(input_shape,n_classes)

# %%
model.compile(optimizer='adam', loss = losses.sparse_categorical_crossentropy, metrics='accuracy' )

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 128)  8320        ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   36896       ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 96)   0           ['conv2d_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 56, 56, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  12416       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   36896       ['re_lu_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['conv2d_4[0][0]',
#                                                                   'concatenate[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 128)  16512       ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   36896       ['re_lu_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 160)  0           ['conv2d_6[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 160)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  20608       ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 32)   36896       ['re_lu_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 192)  0           ['conv2d_8[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 56, 56, 192)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 128)  24704       ['re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 224)  0           ['conv2d_10[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 224)  896        ['concatenate_4[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 56, 56, 224)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 128)  28800       ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 56, 56, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_11[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 256)  0           ['conv2d_12[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 256)  1024       ['concatenate_5[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 56, 56, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 128)  32896       ['re_lu_12[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 128)  0          ['conv2d_13[0][0]']
#  ing2D)
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 128)  512        ['average_pooling2d[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  16512       ['re_lu_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_14[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 160)  0           ['conv2d_15[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 160)  640        ['concatenate_6[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 28, 28, 160)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  20608       ['re_lu_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_16[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 192)  0           ['conv2d_17[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 192)  768        ['concatenate_7[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  24704       ['re_lu_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_18[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 224)  0           ['conv2d_19[0][0]',
#                                                                   'concatenate_7[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 224)  896        ['concatenate_8[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 28, 28, 224)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 128)  28800       ['re_lu_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_20[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 256)  0           ['conv2d_21[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 256)  1024       ['concatenate_9[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 28, 28, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 128)  32896       ['re_lu_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_22[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 288)  0           ['conv2d_23[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 288)  1152       ['concatenate_10[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 28, 28, 288)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 128)  36992       ['re_lu_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_24[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 320)  0           ['conv2d_25[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 320)  1280       ['concatenate_11[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 28, 28, 320)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 128)  41088       ['re_lu_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_26[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 352)  0           ['conv2d_27[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 352)  1408       ['concatenate_12[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 28, 28, 352)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 128)  45184       ['re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_28[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 28, 28, 384)  0           ['conv2d_29[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 384)  1536       ['concatenate_13[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 28, 28, 384)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 128)  49280       ['re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 28, 28, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_30[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 28, 28, 416)  0           ['conv2d_31[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 28, 28, 416)  1664       ['concatenate_14[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 28, 28, 416)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 28, 28, 128)  53376       ['re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 28, 28, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_32[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 28, 28, 448)  0           ['conv2d_33[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 28, 28, 448)  1792       ['concatenate_15[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 28, 28, 448)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 28, 28, 128)  57472       ['re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 28, 28, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_34[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 480)  0           ['conv2d_35[0][0]',
#                                                                   'concatenate_15[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 28, 28, 480)  1920       ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 28, 28, 480)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 28, 28, 128)  61568       ['re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 28, 28, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_36[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 512)  0           ['conv2d_37[0][0]',
#                                                                   'concatenate_16[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 28, 28, 512)  2048       ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 28, 28, 512)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 28, 28, 256)  131328      ['re_lu_37[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 256)  0          ['conv2d_38[0][0]']
#  oling2D)
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 256)  1024       ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 128)  32896       ['re_lu_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_39[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 288)  0           ['conv2d_40[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 288)  1152       ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 14, 14, 288)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 128)  36992       ['re_lu_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_41[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 320)  0           ['conv2d_42[0][0]',
#                                                                   'concatenate_18[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 320)  1280       ['concatenate_19[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 14, 14, 320)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 128)  41088       ['re_lu_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_43[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 352)  0           ['conv2d_44[0][0]',
#                                                                   'concatenate_19[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 352)  1408       ['concatenate_20[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 14, 14, 352)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 128)  45184       ['re_lu_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_45[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 384)  0           ['conv2d_46[0][0]',
#                                                                   'concatenate_20[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 384)  1536       ['concatenate_21[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 14, 14, 128)  49280       ['re_lu_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_47[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 416)  0           ['conv2d_48[0][0]',
#                                                                   'concatenate_21[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 416)  1664       ['concatenate_22[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 14, 14, 416)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 14, 14, 128)  53376       ['re_lu_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_49[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 448)  0           ['conv2d_50[0][0]',
#                                                                   'concatenate_22[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 448)  1792       ['concatenate_23[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 14, 14, 448)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 14, 14, 128)  57472       ['re_lu_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  re_lu_51 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_51[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 480)  0           ['conv2d_52[0][0]',
#                                                                   'concatenate_23[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 480)  1920       ['concatenate_24[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 14, 14, 480)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 14, 14, 128)  61568       ['re_lu_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 14, 14, 32)   36896       ['re_lu_53[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_54[0][0]',
#                                                                   'concatenate_24[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 512)  2048       ['concatenate_25[0][0]']
#  ormalization)
#
#  re_lu_54 (ReLU)                (None, 14, 14, 512)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 14, 14, 128)  65664       ['re_lu_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  re_lu_55 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_55[0][0]']
# ...
#  Normalization)
#
#  re_lu_101 (ReLU)               (None, 7, 7, 736)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 128)    94336       ['re_lu_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 128)   512         ['conv2d_102[0][0]']
#  Normalization)
#
#  re_lu_102 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_102[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 7, 7, 768)    0           ['conv2d_103[0][0]',
#                                                                   'concatenate_48[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 768)   3072        ['concatenate_49[0][0]']
#  Normalization)
#
#  re_lu_103 (ReLU)               (None, 7, 7, 768)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 128)    98432       ['re_lu_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 7, 7, 128)   512         ['conv2d_104[0][0]']
#  Normalization)
#
#  re_lu_104 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_104[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 7, 7, 800)    0           ['conv2d_105[0][0]',
#                                                                   'concatenate_49[0][0]']
#
#  batch_normalization_105 (Batch  (None, 7, 7, 800)   3200        ['concatenate_50[0][0]']
#  Normalization)
#
#  re_lu_105 (ReLU)               (None, 7, 7, 800)    0           ['batch_normalization_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 128)    102528      ['re_lu_105[0][0]']
#
#  batch_normalization_106 (Batch  (None, 7, 7, 128)   512         ['conv2d_106[0][0]']
#  Normalization)
#
#  re_lu_106 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_106[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 7, 832)    0           ['conv2d_107[0][0]',
#                                                                   'concatenate_50[0][0]']
#
#  batch_normalization_107 (Batch  (None, 7, 7, 832)   3328        ['concatenate_51[0][0]']
#  Normalization)
#
#  re_lu_107 (ReLU)               (None, 7, 7, 832)    0           ['batch_normalization_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 7, 7, 128)    106624      ['re_lu_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 7, 7, 128)   512         ['conv2d_108[0][0]']
#  Normalization)
#
#  re_lu_108 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_108[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 7, 864)    0           ['conv2d_109[0][0]',
#                                                                   'concatenate_51[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 864)   3456        ['concatenate_52[0][0]']
#  Normalization)
#
#  re_lu_109 (ReLU)               (None, 7, 7, 864)    0           ['batch_normalization_109[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 128)    110720      ['re_lu_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 128)   512         ['conv2d_110[0][0]']
#  Normalization)
#
#  re_lu_110 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_110[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 7, 896)    0           ['conv2d_111[0][0]',
#                                                                   'concatenate_52[0][0]']
#
#  batch_normalization_111 (Batch  (None, 7, 7, 896)   3584        ['concatenate_53[0][0]']
#  Normalization)
#
#  re_lu_111 (ReLU)               (None, 7, 7, 896)    0           ['batch_normalization_111[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 128)    114816      ['re_lu_111[0][0]']
#
#  batch_normalization_112 (Batch  (None, 7, 7, 128)   512         ['conv2d_112[0][0]']
#  Normalization)
#
#  re_lu_112 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_112[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 7, 928)    0           ['conv2d_113[0][0]',
#                                                                   'concatenate_53[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 928)   3712        ['concatenate_54[0][0]']
#  Normalization)
#
#  re_lu_113 (ReLU)               (None, 7, 7, 928)    0           ['batch_normalization_113[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 128)    118912      ['re_lu_113[0][0]']
#
#  batch_normalization_114 (Batch  (None, 7, 7, 128)   512         ['conv2d_114[0][0]']
#  Normalization)
#
#  re_lu_114 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_114[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 7, 960)    0           ['conv2d_115[0][0]',
#                                                                   'concatenate_54[0][0]']
#
#  batch_normalization_115 (Batch  (None, 7, 7, 960)   3840        ['concatenate_55[0][0]']
#  Normalization)
#
#  re_lu_115 (ReLU)               (None, 7, 7, 960)    0           ['batch_normalization_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 128)    123008      ['re_lu_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 7, 7, 128)   512         ['conv2d_116[0][0]']
#  Normalization)
#
#  re_lu_116 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_116[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 7, 992)    0           ['conv2d_117[0][0]',
#                                                                   'concatenate_55[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 992)   3968        ['concatenate_56[0][0]']
#  Normalization)
#
#  re_lu_117 (ReLU)               (None, 7, 7, 992)    0           ['batch_normalization_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 7, 7, 128)    127104      ['re_lu_117[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 128)   512         ['conv2d_118[0][0]']
#  Normalization)
#
#  re_lu_118 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_118[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_119[0][0]',
#                                                                   'concatenate_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_57[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 20)           20500       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,063,892
# Trainable params: 6,982,420
# Non-trainable params: 81,472
# __________________________________________________________________________________________________

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',min_delta = 0.05, mode = "max" ,patience=20, restore_best_weights=True)
callbacks = [early_stop]
history = model.fit(ds_train, validation_data=ds_val, epochs=120, callbacks = callbacks)
# Out:
# Epoch 1/120
# 409/409 [==============================] - 241s 487ms/step - loss: 2.8591 - accuracy: 0.1896 - val_loss: 6.5625 - val_accuracy: 0.1643
# Epoch 2/120
# 409/409 [==============================] - 194s 449ms/step - loss: 2.4258 - accuracy: 0.2401 - val_loss: 3.6587 - val_accuracy: 0.1714
# Epoch 3/120
# 409/409 [==============================] - 193s 449ms/step - loss: 2.2931 - accuracy: 0.2767 - val_loss: 3.6594 - val_accuracy: 0.1786
# Epoch 4/120
# 409/409 [==============================] - 193s 449ms/step - loss: 2.1616 - accuracy: 0.3096 - val_loss: 2.4830 - val_accuracy: 0.2721
# Epoch 5/120
# 409/409 [==============================] - 193s 448ms/step - loss: 2.0232 - accuracy: 0.3438 - val_loss: 2.0672 - val_accuracy: 0.3357
# Epoch 6/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.9457 - accuracy: 0.3677 - val_loss: 2.3694 - val_accuracy: 0.3221
# Epoch 7/120
# 409/409 [==============================] - 194s 449ms/step - loss: 1.8572 - accuracy: 0.3953 - val_loss: 2.1623 - val_accuracy: 0.3729
# Epoch 8/120
# 409/409 [==============================] - 193s 449ms/step - loss: 1.8111 - accuracy: 0.4162 - val_loss: 1.9161 - val_accuracy: 0.4129
# Epoch 9/120
# 409/409 [==============================] - 194s 448ms/step - loss: 1.7805 - accuracy: 0.4156 - val_loss: 3.4186 - val_accuracy: 0.2436
# Epoch 10/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.7579 - accuracy: 0.4321 - val_loss: 2.1633 - val_accuracy: 0.3829
# Epoch 11/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.6203 - accuracy: 0.4757 - val_loss: 1.5808 - val_accuracy: 0.5021
# Epoch 12/120
# 409/409 [==============================] - 194s 449ms/step - loss: 1.5111 - accuracy: 0.5074 - val_loss: 1.5386 - val_accuracy: 0.5307
# Epoch 13/120
# 409/409 [==============================] - 194s 449ms/step - loss: 1.4441 - accuracy: 0.5362 - val_loss: 1.2767 - val_accuracy: 0.5986
# Epoch 14/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.3209 - accuracy: 0.5706 - val_loss: 1.4031 - val_accuracy: 0.5564
# Epoch 15/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.2496 - accuracy: 0.6041 - val_loss: 1.4526 - val_accuracy: 0.5629
# Epoch 16/120
# 409/409 [==============================] - 193s 449ms/step - loss: 1.1760 - accuracy: 0.6173 - val_loss: 1.2028 - val_accuracy: 0.6314
# Epoch 17/120
# 409/409 [==============================] - 193s 448ms/step - loss: 1.0815 - accuracy: 0.6598 - val_loss: 1.3366 - val_accuracy: 0.5907
# Epoch 18/120
# 409/409 [==============================] - 194s 449ms/step - loss: 1.0601 - accuracy: 0.6563 - val_loss: 2.0490 - val_accuracy: 0.4514
# Epoch 19/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.9840 - accuracy: 0.6839 - val_loss: 1.2774 - val_accuracy: 0.6250
# Epoch 20/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.8993 - accuracy: 0.7064 - val_loss: 1.1792 - val_accuracy: 0.6314
# Epoch 21/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.8712 - accuracy: 0.7166 - val_loss: 1.4264 - val_accuracy: 0.5843
# Epoch 22/120
# 409/409 [==============================] - 194s 450ms/step - loss: 0.8222 - accuracy: 0.7308 - val_loss: 1.0772 - val_accuracy: 0.6743
# Epoch 23/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.7853 - accuracy: 0.7469 - val_loss: 1.0533 - val_accuracy: 0.6779
# Epoch 24/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.7090 - accuracy: 0.7663 - val_loss: 1.0223 - val_accuracy: 0.6793
# Epoch 25/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.6632 - accuracy: 0.7804 - val_loss: 1.3053 - val_accuracy: 0.6571
# Epoch 26/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.6366 - accuracy: 0.7907 - val_loss: 1.6544 - val_accuracy: 0.6621
# Epoch 27/120
# 409/409 [==============================] - 194s 450ms/step - loss: 0.5889 - accuracy: 0.8014 - val_loss: 1.0381 - val_accuracy: 0.7179
# Epoch 28/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.5738 - accuracy: 0.8070 - val_loss: 1.2460 - val_accuracy: 0.6700
# Epoch 29/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.5264 - accuracy: 0.8274 - val_loss: 0.9914 - val_accuracy: 0.7221
# Epoch 30/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.4886 - accuracy: 0.8366 - val_loss: 1.1074 - val_accuracy: 0.7086
# Epoch 31/120
# 409/409 [==============================] - 194s 450ms/step - loss: 0.4882 - accuracy: 0.8389 - val_loss: 1.0488 - val_accuracy: 0.7450
# Epoch 32/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.4232 - accuracy: 0.8591 - val_loss: 1.3320 - val_accuracy: 0.6664
# Epoch 33/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.4011 - accuracy: 0.8640 - val_loss: 1.3193 - val_accuracy: 0.6836
# Epoch 34/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.3863 - accuracy: 0.8702 - val_loss: 1.4094 - val_accuracy: 0.6757
# Epoch 35/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.3507 - accuracy: 0.8842 - val_loss: 1.1900 - val_accuracy: 0.7021
# Epoch 36/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.3294 - accuracy: 0.8921 - val_loss: 1.1687 - val_accuracy: 0.7271
# Epoch 37/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.3043 - accuracy: 0.8985 - val_loss: 1.5199 - val_accuracy: 0.6771
# Epoch 38/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.3201 - accuracy: 0.8966 - val_loss: 1.1346 - val_accuracy: 0.7429
# Epoch 39/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.2931 - accuracy: 0.9042 - val_loss: 1.1850 - val_accuracy: 0.7257
# Epoch 40/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.2633 - accuracy: 0.9102 - val_loss: 1.0704 - val_accuracy: 0.7414
# Epoch 41/120
# 409/409 [==============================] - 193s 449ms/step - loss: 0.2764 - accuracy: 0.9125 - val_loss: 1.2685 - val_accuracy: 0.7193
# Epoch 42/120
# 409/409 [==============================] - 194s 449ms/step - loss: 0.2774 - accuracy: 0.9079 - val_loss: 1.6231 - val_accuracy: 0.6564
# Epoch 43/120
# 409/409 [==============================] - 194s 450ms/step - loss: 0.2365 - accuracy: 0.9232 - val_loss: 1.1297 - val_accuracy: 0.7471
# Epoch 44/120
# 409/409 [==============================] - 194s 451ms/step - loss: 0.2309 - accuracy: 0.9233 - val_loss: 1.0888 - val_accuracy: 0.7507
# Epoch 45/120
#  83/409 [=====>........................] - ETA: 2:18 - loss: 0.1812 - accuracy: 0.9330

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))

axs[0].plot(history.history['loss'])
axs[0].plot(history.history['val_loss'])
axs[0].title.set_text('Training Loss vs Validation Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend(['Train','Val'])

axs[1].plot(history.history['accuracy'])
axs[1].plot(history.history['val_accuracy'])
axs[1].title.set_text('Training Accuracy vs Validation Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend(['Train', 'Val'])

# %%
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""SAVE MODEL """""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""

# %%
model.save("#PATH_TOFILE")
